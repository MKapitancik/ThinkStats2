# %% [markdown]
# # Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from __future__ import print_function, division

import nsfg

# %% [markdown]
# ## Examples from Chapter 1
#
# Read NSFG data into a Pandas DataFrame.

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth     ...       laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN     ...                0           0        0
# 1       NaN       1.0       NaN     ...                0           0        0
# 2       NaN       3.0       5.0     ...                0           0        0
# 3       NaN       1.0       NaN     ...                0           0        0
# 4       NaN       1.0       NaN     ...                0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# 0  3410.389399      3869.349602   6448.271112       2     9      NaN
# 1  3410.389399      3869.349602   6448.271112       2     9      NaN
# 2  7226.301740      8567.549110  12999.542264       2    12      NaN
# 3  7226.301740      8567.549110  12999.542264       2    12      NaN
# 4  7226.301740      8567.549110  12999.542264       2    12      NaN
#
#    totalwgt_lb
# 0       8.8125
# 1       7.8750
# 2       9.1250
# 3       7.0000
# 4       6.1875
#
# [5 rows x 244 columns]

# %% [markdown]
# Print the column names.

# %%
preg.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %% [markdown]
# Select a single column name.

# %%
preg.columns[1]
# Out:
# 'pregordr'

# %% [markdown]
# Select a column and check what type it is.

# %%
pregordr = preg['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Print a column.

# %%
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
# 5        1
# 6        2
# 7        3
# 8        1
# 9        2
# 10       1
# 11       1
# 12       2
# 13       3
# 14       1
# 15       2
# 16       3
# 17       1
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       3
# 26       1
# 27       1
# 28       2
# 29       3
#         ..
# 13563    2
# 13564    3
# 13565    1
# 13566    1
# 13567    1
# 13568    2
# 13569    1
# 13570    2
# 13571    3
# 13572    4
# 13573    1
# 13574    2
# 13575    1
# 13576    1
# 13577    2
# 13578    1
# 13579    2
# 13580    1
# 13581    2
# 13582    3
# 13583    1
# 13584    2
# 13585    1
# 13586    2
# 13587    3
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, Length: 13593, dtype: int64

# %% [markdown]
# Select a single element from a column.

# %%
pregordr[0]
# Out:
# 1

# %% [markdown]
# Select a slice from a column.

# %%
pregordr[2:5]
# Out:
# 2    1
# 3    2
# 4    3
# Name: pregordr, dtype: int64

# %% [markdown]
# Select a column using dot notation.

# %%
pregordr = preg.pregordr

# %% [markdown]
# Count the number of times each value occurs.

# %%
preg.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %% [markdown]
# Check the values of another variable.

# %%
preg.birthwgt_lb.value_counts().sort_index()
# Out:
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: birthwgt_lb, dtype: int64

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %%
caseid = 10229
preg_map = nsfg.MakePregMap(preg)
indices = preg_map[caseid]
preg.outcome[indices].values
# Out:
# array([4, 4, 4, 4, 4, 4, 1], dtype=int64)

# %% [markdown]
# ## Exercises

# %% [markdown]
# Select the `birthord` column, print the value counts, and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611933)

# %%
preg.birthord.value_counts()
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %% [markdown]
# We can also use `isnull` to count the number of nans.

# %%
preg.birthord.isnull().sum()
# Out:
# 4445

# %% [markdown]
# Select the `prglngth` column, print the value counts, and compare to results published in the [codebook](\http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
preg.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# To compute the mean of a column, you can invoke the `mean` method on a Series.  For example, here is the mean birthweight in pounds:

# %%
preg.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
preg['totalwgt_kg'] = preg['birthwgt_lb'] * 0.45359237
preg.totalwgt_kg.mean()
# Out:
# 3.098998597458168

# %% [markdown]
# `nsfg.py` also provides `ReadFemResp`, which reads the female respondents file and returns a `DataFrame`:

# %%
resp = nsfg.ReadFemResp()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-c2bcd80e7a0d> in <module>()
#       1 #%%
# ----> 2 resp = nsfg.ReadFemResp()
#
# c:\_Repos\ThinkStats2\code\nsfg.py in ReadFemResp(dct_file, dat_file, nrows)
#      26     """
#      27     dct = thinkstats2.ReadStataDct(dct_file)
# ---> 28     df = dct.ReadFixedWidth(dat_file, compression='gzip', nrows=nrows)
#      29     CleanFemResp(df)
#      30     return df
#
# c:\_Repos\ThinkStats2\code\thinkstats2.py in ReadFixedWidth(self, filename, **options)
#    2629                              colspecs=self.colspecs,
#    2630                              names=self.names,
# -> 2631                              **options)
#    2632         return df
#    2633
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in read_fwf(filepath_or_buffer, colspecs, widths, **kwds)
#     708     kwds['colspecs'] = colspecs
#     709     kwds['engine'] = 'python-fwf'
# --> 710     return _read(filepath_or_buffer, kwds)
#     711
#     712
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2237     def read(self, rows=None):
#    2238         try:
# -> 2239             content = self._get_lines(rows)
#    2240         except StopIteration:
#    2241             if self._first_chunk:
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in _get_lines(self, rows)
#    2969                         while True:
#    2970                             new_row = self._next_iter_line(
# -> 2971                                 row_num=self.pos + rows + 1)
#    2972                             rows += 1
#    2973
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2693
#    2694         try:
# -> 2695             return next(self.data)
#    2696         except csv.Error as e:
#    2697             if self.warn_bad_lines or self.error_bad_lines:
#
# C:\Program Files (x86)\Python36-32\lib\site-packages\pandas\io\parsers.py in __next__(self)
#    3428                 line = next(self.f)
#    3429         else:
# -> 3430             line = next(self.f)
#    3431         # Note: 'colspecs' is a sequence of half-open intervals.
#    3432         return [line[fromm:to].strip(self.delimiter)
#
# C:\Program Files (x86)\Python36-32\lib\gzip.py in read1(self, size)
#     287         if size < 0:
#     288             size = io.DEFAULT_BUFFER_SIZE
# --> 289         return self._buffer.read1(size)
#     290
#     291     def peek(self, n):
#
# C:\Program Files (x86)\Python36-32\lib\_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# C:\Program Files (x86)\Python36-32\lib\gzip.py in read(self, size)
#     469             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     470
# --> 471             uncompress = self._decompressor.decompress(buf, size)
#     472             if self._decompressor.unconsumed_tail != b"":
#     473                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %% [markdown]
# `DataFrame` provides a method `head` that displays the first five rows:

# %%
resp.head()
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
# 1    5012        1         5         1            5          5.0     42
# 2   11586        1         5         1            5          5.0     43
# 3    6794        5         5         4            1          5.0     15
# 4     616        1         5         4            1          5.0     20
#
#    age_r  cmbirth  agescrn     ...      pubassis_i      basewgt  \
# 0     27      902       27     ...               0  3247.916977
# 1     42      718       42     ...               0  2335.279149
# 2     43      708       43     ...               0  2335.279149
# 3     15     1042       15     ...               0  3783.152221
# 4     20      991       20     ...               0  5341.329968
#
#    adj_mod_basewgt     finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime  \
# 0      5123.759559  5556.717241       2    18     1234     1222    18:26:36
# 1      2846.799490  4744.191350       2    18     1233     1221    16:30:59
# 2      2846.799490  4744.191350       2    18     1234     1222    18:19:09
# 3      5071.464231  5923.977368       2    18     1234     1222    15:54:43
# 4      6437.335772  7229.128072       2    18     1233     1221    14:19:44
#
#     intvlngth
# 0  110.492667
# 1   64.294000
# 2   75.149167
# 3   28.642833
# 4   69.502667
#
# [5 rows x 3087 columns]

# %% [markdown]
# Select the `age_r` column from `resp` and print the value counts.  How old are the youngest and oldest respondents?

# %%
resp.age_r
print(min(resp.age_r))
print(max(resp.age_r))
# Out:
# 15
# 44

# %% [markdown]
# We can use the `caseid` to match up rows from `resp` and `preg`.  For example, we can select the row from `resp` for `caseid` 2298 like this:

# %%
resp[resp.caseid==2298]
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
#
#    age_r  cmbirth  agescrn     ...      pubassis_i      basewgt  \
# 0     27      902       27     ...               0  3247.916977
#
#    adj_mod_basewgt     finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime  \
# 0      5123.759559  5556.717241       2    18     1234     1222    18:26:36
#
#     intvlngth
# 0  110.492667
#
# [1 rows x 3087 columns]

# %% [markdown]
# And we can get the corresponding rows from `preg` like this:

# %%
preg[preg.caseid==2298]
# Out:
#       caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 2610    2298         1        NaN        NaN       NaN       NaN       6.0
# 2611    2298         2        NaN        NaN       NaN       NaN       6.0
# 2612    2298         3        NaN        NaN       NaN       NaN       6.0
# 2613    2298         4        NaN        NaN       NaN       NaN       6.0
#
#       pregend2  nbrnaliv  multbrth     ...       religion_i  metro_i  \
# 2610       NaN       1.0       NaN     ...                0        0
# 2611       NaN       1.0       NaN     ...                0        0
# 2612       NaN       1.0       NaN     ...                0        0
# 2613       NaN       1.0       NaN     ...                0        0
#
#           basewgt  adj_mod_basewgt     finalwgt  secu_p  sest  cmintvw  \
# 2610  3247.916977      5123.759559  5556.717241       2    18      NaN
# 2611  3247.916977      5123.759559  5556.717241       2    18      NaN
# 2612  3247.916977      5123.759559  5556.717241       2    18      NaN
# 2613  3247.916977      5123.759559  5556.717241       2    18      NaN
#
#       totalwgt_lb  totalwgt_kg
# 2610       6.8750     2.721554
# 2611       5.5000     2.267962
# 2612       4.1875     1.814369
# 2613       6.8750     2.721554
#
# [4 rows x 245 columns]

# %% [markdown]
# How old is the respondent with `caseid` 1?

# %%
resp[resp.caseid==1].age_r
# Out:
# 1069    44
# Name: age_r, dtype: int64

# %% [markdown]
# What are the pregnancy lengths for the respondent with `caseid` 2298?

# %%
preg[preg.caseid == 2298].prglngth
# Out:
# 2610    40
# 2611    36
# 2612    30
# 2613    40
# Name: prglngth, dtype: int64

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with `caseid` 5012?

# %%
preg[preg.caseid == 5012].birthwgt_lb
# Out:
# 5515    6.0
# Name: birthwgt_lb, dtype: float64

# %% [markdown]
# # Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from __future__ import print_function, division

import nsfg

# %% [markdown]
# ## Examples from Chapter 1
#
# Read NSFG data into a Pandas DataFrame.

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth     ...       laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN     ...                0           0        0
# 1       NaN       1.0       NaN     ...                0           0        0
# 2       NaN       3.0       5.0     ...                0           0        0
# 3       NaN       1.0       NaN     ...                0           0        0
# 4       NaN       1.0       NaN     ...                0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# 0  3410.389399      3869.349602   6448.271112       2     9      NaN
# 1  3410.389399      3869.349602   6448.271112       2     9      NaN
# 2  7226.301740      8567.549110  12999.542264       2    12      NaN
# 3  7226.301740      8567.549110  12999.542264       2    12      NaN
# 4  7226.301740      8567.549110  12999.542264       2    12      NaN
#
#    totalwgt_lb
# 0       8.8125
# 1       7.8750
# 2       9.1250
# 3       7.0000
# 4       6.1875
#
# [5 rows x 244 columns]

# %% [markdown]
# Print the column names.

# %%
preg.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %% [markdown]
# Select a single column name.

# %%
preg.columns[1]
# Out:
# 'pregordr'

# %% [markdown]
# Select a column and check what type it is.

# %%
pregordr = preg['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Print a column.

# %%
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
# 5        1
# 6        2
# 7        3
# 8        1
# 9        2
# 10       1
# 11       1
# 12       2
# 13       3
# 14       1
# 15       2
# 16       3
# 17       1
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       3
# 26       1
# 27       1
# 28       2
# 29       3
#         ..
# 13563    2
# 13564    3
# 13565    1
# 13566    1
# 13567    1
# 13568    2
# 13569    1
# 13570    2
# 13571    3
# 13572    4
# 13573    1
# 13574    2
# 13575    1
# 13576    1
# 13577    2
# 13578    1
# 13579    2
# 13580    1
# 13581    2
# 13582    3
# 13583    1
# 13584    2
# 13585    1
# 13586    2
# 13587    3
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, Length: 13593, dtype: int64

# %% [markdown]
# Select a single element from a column.

# %%
pregordr[0]
# Out:
# 1

# %% [markdown]
# Select a slice from a column.

# %%
pregordr[2:5]
# Out:
# 2    1
# 3    2
# 4    3
# Name: pregordr, dtype: int64

# %% [markdown]
# Select a column using dot notation.

# %%
pregordr = preg.pregordr

# %% [markdown]
# Count the number of times each value occurs.

# %%
preg.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %% [markdown]
# Check the values of another variable.

# %%
preg.birthwgt_lb.value_counts().sort_index()
# Out:
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: birthwgt_lb, dtype: int64

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %%
caseid = 10229
preg_map = nsfg.MakePregMap(preg)
indices = preg_map[caseid]
preg.outcome[indices].values
# Out:
# array([4, 4, 4, 4, 4, 4, 1], dtype=int64)

# %% [markdown]
# ## Exercises

# %% [markdown]
# Select the `birthord` column, print the value counts, and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611933)

# %%
preg.birthord.value_counts()
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %% [markdown]
# We can also use `isnull` to count the number of nans.

# %%
preg.birthord.isnull().sum()
# Out:
# 4445

# %% [markdown]
# Select the `prglngth` column, print the value counts, and compare to results published in the [codebook](\http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
preg.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# To compute the mean of a column, you can invoke the `mean` method on a Series.  For example, here is the mean birthweight in pounds:

# %%
preg.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
preg['totalwgt_kg'] = preg['birthwgt_lb'] * 0.45359237
preg.totalwgt_kg.mean()
# Out:
# 3.098998597458168

# %% [markdown]
# `nsfg.py` also provides `ReadFemResp`, which reads the female respondents file and returns a `DataFrame`:

# %%
resp = nsfg.ReadFemResp()

# %% [markdown]
# `DataFrame` provides a method `head` that displays the first five rows:

# %%
resp.head()

# %% [markdown]
# Select the `age_r` column from `resp` and print the value counts.  How old are the youngest and oldest respondents?

# %%
resp.age_r
print(min(resp.age_r))
print(max(resp.age_r))

# %% [markdown]
# We can use the `caseid` to match up rows from `resp` and `preg`.  For example, we can select the row from `resp` for `caseid` 2298 like this:

# %%
resp[resp.caseid==2298]

# %% [markdown]
# And we can get the corresponding rows from `preg` like this:

# %%
preg[preg.caseid==2298]

# %% [markdown]
# How old is the respondent with `caseid` 1?

# %%
resp[resp.caseid==1].age_r

# %% [markdown]
# What are the pregnancy lengths for the respondent with `caseid` 2298?

# %%
preg[preg.caseid == 2298].prglngth

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with `caseid` 5012?

# %%
preg[preg.caseid == 5012].birthwgt_lb
